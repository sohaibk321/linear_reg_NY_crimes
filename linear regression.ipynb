# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format
df = pd.read_csv('table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.csv')

# %%
df.columns = df.columns.str.replace('\n', ' ')
df.drop('Unnamed: 13', axis=1, inplace=True)
df.dtypes
# Out:
# City                                     object
# Population                               object
# Violent crime                            object
# Murder and nonnegligent manslaughter    float64
# Rape (revised definition)1              float64
# Rape (legacy definition)2                object
# Robbery                                  object
# Aggravated assault                       object
# Property crime                           object
# Burglary                                 object
# Larceny- theft                           object
# Motor vehicle theft                      object
# Arson3                                  float64
# dtype: object

# %%
#remove commas and convert to float
fix = ['Population', 'Violent crime', 'Rape (legacy definition)2', 'Robbery', 'Aggravated assault', 
       'Property crime', 'Burglary', 'Larceny- theft', 'Motor vehicle theft']
for key in fix:
    df[key] = pd.to_numeric(df[key].astype(str).str.replace(',',''), errors='ignore')
df.dtypes
# Out:
# City                                     object
# Population                               object
# Violent crime                            object
# Murder and nonnegligent manslaughter    float64
# Rape (revised definition)1              float64
# Rape (legacy definition)2                object
# Robbery                                  object
# Aggravated assault                       object
# Property crime                           object
# Burglary                                 object
# Larceny- theft                           object
# Motor vehicle theft                      object
# Arson3                                  float64
# dtype: object

# %%
for key in fix:
    df[key] = pd.to_numeric(df[key].astype(str).str.replace(',',''), errors='coerce')
df.dropna(axis=1, how='all', inplace=True)
df.dropna(axis=0, how='all', inplace=True)

# %%
df.dtypes
# Out:
# City                                     object
# Population                              float64
# Violent crime                           float64
# Murder and nonnegligent manslaughter    float64
# Rape (legacy definition)2               float64
# Robbery                                 float64
# Aggravated assault                      float64
# Property crime                          float64
# Burglary                                float64
# Larceny- theft                          float64
# Motor vehicle theft                     float64
# Arson3                                  float64
# dtype: object

# %%
df['Population^2'] = df['Population'].map(lambda x: x**2)
df['Murder'] = np.where(df['Murder and nonnegligent manslaughter']>0, 1, 0)
df['Robbery_feature'] = np.where(df['Robbery']>0, 1, 0)
df
# Out:
#                            City  Population  Violent crime  \
# 0                 Adams Village    1861.000          0.000
# 1      Addison Town and Village    2577.000          3.000
# 2                 Akron Village    2846.000          3.000
# 3                        Albany   97956.000        791.000
# 4                Albion Village    6388.000         23.000
# 5                Alfred Village    4089.000          5.000
# 6              Allegany Village    1781.000          3.000
# 7                  Amherst Town  118296.000        107.000
# 8            Amityville Village    9519.000          9.000
# 9                     Amsterdam   18182.000         30.000
# 10               Arcade Village    2053.000          0.000
# 11              Ardsley Village    4523.000          5.000
# 12            Asharoken Village     658.000          0.000
# 13               Attica Village    2522.000          2.000
# 14                       Auburn   27270.000         96.000
# 15                 Avon Village    3333.000          1.000
# 16        Baldwinsville Village    7473.000          5.000
# 17         Ballston Spa Village    5418.000          8.000
# 18                      Batavia   15374.000         57.000
# 19                 Bath Village    5733.000         15.000
# 20                 Bedford Town   17627.000          5.000
# 21               Bethlehem Town   34243.000         13.000
# 22                   Binghamton   46304.000        284.000
# 23                  Black River    1410.000          0.000
# 24          Blooming Grove Town   12001.000          8.000
# 25              Bolivar Village    1022.000          1.000
# 342               0.000          77.000    13.000          61.000
# 343               1.000         541.000     9.000         529.000
# 344               7.000          17.000     8.000           9.000
# 345               2.000          58.000    13.000          45.000
# 346             615.000        2368.000   470.000        1662.000
# 347              13.000         334.000    45.000         287.000
#
#      Motor vehicle theft  Arson3    Population^2  Murder  Robbery_feature
# 0                  0.000   0.000     3463321.000       0                0
# 1                  1.000   0.000     6640929.000       0                0
# 2                  0.000   0.000     8099716.000       0                0
# 3                142.000     nan  9595377936.000       1                1
# 4                  5.000     nan    40806544.000       0                1
# 5                  0.000     nan    16719921.000       0                1
# 6                  0.000   0.000     3171961.000       0                0
# 7                 32.000   3.000 13993943616.000       1                1
# 8                  6.000   1.000    90611361.000       0                1
# 9                 15.000   0.000   330585124.000       0                1
# 10                 1.000   0.000     4214809.000       0                0
# 11                 1.000   0.000    20457529.000       0                1
# 12                 0.000   0.000      432964.000       0                0
# 13                 1.000   0.000     6360484.000       0                0
# 14                 6.000     nan   743652900.000       1                1
# 15                 2.000     nan    11108889.000       0                1
# 16                 1.000   0.000    55845729.000       0                1
# 17                 0.000   1.000    29354724.000       0                1
# 18                 2.000     nan   236359876.000       0                1
# 19                 2.000   2.000    32867289.000       0                1
# 20                 3.000     nan   310711129.000       0                1
# 21                 4.000     nan  1172583049.000       0                1
# 22                57.000     nan  2144060416.000       1                1
# 23                 0.000   0.000     1988100.000       0                0
# 24                 7.000     nan   144024001.000       0                0
# 25                 0.000   0.000     1044484.000       0                0
# 26                 0.000   0.000     5405625.000       0                0
# 27                 0.000   0.000     4218916.000       0                0
# 28                 2.000   0.000     4264225.000       0                1
# 29                 0.000   0.000     5560164.000       0                0
# ..                   ...     ...             ...     ...              ...
# 318                2.000     nan    13264164.000       0                0
# 319                0.000   0.000      378225.000       0                0
# 320                2.000     nan   148718025.000       0                1
# 321               82.000     nan  3805162596.000       1                1
# 322                9.000     nan   782880400.000       0                1
# 323                5.000     nan    47430769.000       1                1
# 324               26.000   1.000   780643600.000       0                1
# 325                0.000     nan     9072144.000       0                0
# 326                0.000   0.000    11923209.000       0                0
# 327                2.000   0.000    33965584.000       0                1
# 328                1.000   0.000    70425664.000       0                0
# 329                2.000     nan    26780625.000       0                1
# 330               43.000     nan   794056041.000       0                1
# 331               21.000     nan   104960025.000       1                1
# 332                2.000     nan     3467044.000       0                0
# 333                4.000     nan    18809569.000       0                1
# 334                7.000     nan  1916425729.000       0                1
# 335                0.000   0.000     3229209.000       0                0
# 336                3.000   1.000    20921476.000       0                0
# 337                3.000   0.000     2999824.000       0                0
# 338               20.000   0.000  2008922041.000       1                1
# 339                1.000     nan     6780816.000       0                0
# 340               21.000     nan  3313038481.000       1                1
# 341                1.000   0.000    13935289.000       0                0
# 342                3.000   0.000    83557881.000       0                0
# 343                3.000     nan   114169225.000       0                1
# 344                0.000   0.000      687241.000       0                0
# 345                0.000     nan    35176761.000       0                0
# 346              236.000  10.000 39654349956.000       1                1
# 347                2.000     nan  1342709449.000       0                1
#
# [348 rows x 15 columns]
